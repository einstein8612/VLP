# %%
import torch

import numpy as np
import pandas as pd
from models.mlp import MLP

from tqdm import tqdm
from matplotlib import pyplot as plt

# %%
decay = np.load("./dataset/exported/age-series/decay.npy")

# %%
for i in range(0, int(decay.shape[1]/2)):
    plt.plot(np.arange(decay.shape[0]) * 100, decay[:, i], alpha=0.5, label=f"LED {i}")
plt.xlabel("Time (hours)")
plt.ylabel("Decay factor (relative to 0h)")
plt.title("Decay of the LEDs")
plt.legend(bbox_to_anchor=(1.05, 1.025), loc='upper left')
